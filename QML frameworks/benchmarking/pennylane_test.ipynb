# %%
from typing import Callable, List
from tqdm.auto import tqdm
import pandas as pd

from bench_func import run_benchmark

import pennylane as qml
from pennylane import numpy as np
import torch
import time

# %%
def create_circuit(n_qubits):
    '''Example function for creating test circuit'''

    dev = qml.device("lightning.qubit", wires=n_qubits)
    
    @qml.qnode(dev, interface="torch", diff_method="adjoint")
    def circuit(params):
        # wall of single qubit operations
        for i in range(n_qubits):
            qml.RY(params[0, i]*np.pi, wires=i)
            
        # ladder of entangling operations
        for i in range(n_qubits):
            qml.IsingXX(params[1, i]*np.pi, wires=[i, (i+1)%n_qubits])

        return qml.expval(qml.PauliZ(0))
    
    return circuit

steps = 200

def test_time(n_qubits):
    circuit = create_circuit(n_qubits)
    params = torch.rand((2, n_qubits), requires_grad=True)
    def cost(params):
        return (1 - circuit(params))**2
    
    opt = torch.optim.Adam([params], lr = 0.1)
    beg_steps = 5
    for i in range(steps+beg_steps):
        if (i == beg_steps):
            beg = time.time()
        opt.zero_grad()
        loss = cost(params)
        loss.backward()
        opt.step()
    end = time.time()
    return (end-beg)*1000

# %%
# circuit visualization
n_qubits = 5
circuit = create_circuit(n_qubits)
params = torch.rand((2, n_qubits), requires_grad=True)
fig, ax = qml.draw_mpl(circuit)(params)
fig.show()
# Out:
# /tmp/ipykernel_476524/3699645154.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
file_name="pennylane_best.csv"

def create_circuit(n_qubits):
    dev = qml.device("lightning.qubit", wires=n_qubits)
    
    @qml.qnode(dev, interface="torch", diff_method="adjoint")
    def circuit(params):
        # wall of single qubit operations
        for i in range(n_qubits):
            qml.RY(params[0, i]*np.pi, wires=i)
            
        # ladder of entangling operations
        for i in range(n_qubits):
            qml.IsingXX(params[1, i]*np.pi, wires=[i, (i+1)%n_qubits])

        return qml.expval(qml.PauliZ(0))
    
    return circuit


run_benchmark(range(2, 22), test_time, file_name)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# [2, 587.4271392822266]
# [3, 641.1929130554199]
# [4, 541.175127029419]
# [5, 580.1444053649902]
# [6, 715.705156326294]
# [7, 755.2697658538818]
# [8, 725.5361080169678]
# [9, 795.813798904419]
# [10, 867.6464557647705]
# [11, 1055.2144050598145]
# [12, 1323.6024379730225]
# [13, 1826.4291286468506]
# [14, 1683.053731918335]
# [15, 2292.7603721618652]
# [16, 3693.636655807495]
# [17, 9262.73226737976]
# [18, 17789.661645889282]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 21
#      16         return qml.expval(qml.PauliZ(0))
#      18     return circuit
# ---> 21 run_benchmark(range(2, 22), test_time, file_name)
#
# File /mnt/c/Users/amirf/YandexDisk/Documents/quantum_internship/QML_review_report/qml_frameworks_benchmarking/bench_func.py:9, in run_benchmark(qubits_array, test_time, file_name)
#       7 data = []
#       8 for n_qubits in tqdm(qubits_array):
# ----> 9     duration = test_time(n_qubits)
#      11     data.append([n_qubits, duration])
#      12     print([n_qubits, duration])
#
# Cell In[2], line 34, in test_time(n_qubits)
#      32     beg = time.time()
#      33 opt.zero_grad()
# ---> 34 loss = cost(params)
#      35 loss.backward()
#      36 opt.step()
#
# Cell In[2], line 26, in test_time.<locals>.cost(params)
#      25 def cost(params):
# ---> 26     return (1 - circuit(params))**2
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/site-packages/pennylane/qnode.py:867, in QNode.__call__(self, *args, **kwargs)
#     865     self.execute_kwargs.pop("mode")
#     866 # pylint: disable=unexpected-keyword-arg
# --> 867 res = qml.execute(
#     868     [self.tape],
#     869     device=self.device,
#     870     gradient_fn=self.gradient_fn,
#     871     interface=self.interface,
#     872     gradient_kwargs=self.gradient_kwargs,
#     873     override_shots=override_shots,
#     874     **self.execute_kwargs,
#     875 )
#     877 res = res[0]
#     879 if old_interface == "auto":
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/site-packages/pennylane/interfaces/execution.py:483, in execute(tapes, device, gradient_fn, interface, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform)
#     480     elif mapped_interface == "jax":
#     481         _execute = _get_jax_execute_fn(interface, tapes)
# --> 483     res = _execute(
#     484         tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n=1, max_diff=max_diff
#     485     )
#     487 except ImportError as e:
#     488     raise qml.QuantumFunctionError(
#     489         f"{mapped_interface} not found. Please install the latest "
#     490         f"version of {mapped_interface} to enable the '{mapped_interface}' interface."
#     491     ) from e
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/site-packages/pennylane/interfaces/torch.py:499, in execute(tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n, max_diff)
#     487     parameters.extend(tape.get_parameters())
#     489 kwargs = {
#     490     "tapes": tapes,
#     491     "device": device,
#    (...)
#     496     "max_diff": max_diff,
#     497 }
# --> 499 return ExecuteTapes.apply(kwargs, *parameters)
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/site-packages/pennylane/interfaces/torch.py:262, in pytreeify.<locals>.new_apply(*inp)
#     259 def new_apply(*inp):
#     260     # Inputs already flat
#     261     out_struct_holder = []
# --> 262     flat_out = orig_apply(out_struct_holder, *inp)
#     263     return pytree.tree_unflatten(flat_out, out_struct_holder[0])
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/site-packages/torch/autograd/function.py:506, in Function.apply(cls, *args, **kwargs)
#     503 if not torch._C._are_functorch_transforms_active():
#     504     # See NOTE: [functorch vjp and autograd interaction]
#     505     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 506     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     508 if cls.setup_context == _SingleLevelFunction.setup_context:
#     509     raise RuntimeError(
#     510         'In order to use an autograd.Function with functorch transforms '
#     511         '(vmap, grad, jvp, jacrev, ...), it must override the setup_context '
#     512         'staticmethod. For more details, please see '
#     513         'https://pytorch.org/docs/master/notes/extending.func.html')
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/site-packages/pennylane/interfaces/torch.py:266, in pytreeify.<locals>.new_forward(ctx, out_struct_holder, *inp)
#     265 def new_forward(ctx, out_struct_holder, *inp):
# --> 266     out = orig_fw(ctx, *inp)
#     267     flat_out, out_struct = pytree.tree_flatten(out)
#     268     ctx._out_struct = out_struct
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/site-packages/pennylane/interfaces/torch.py:343, in ExecuteTapes.forward(ctx, kwargs, *parameters)
#     340 ctx._n = kwargs.get("_n", 1)
#     342 unwrapped_tapes = tuple(convert_to_numpy_parameters(t) for t in ctx.tapes)
# --> 343 res, ctx.jacs = ctx.execute_fn(unwrapped_tapes, **ctx.gradient_kwargs)
#     345 # if any input tensor uses the GPU, the output should as well
#     346 ctx.torch_device = None
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/site-packages/pennylane/_device.py:571, in Device.execute_and_gradients(self, circuits, method, **kwargs)
#     566 for circuit in circuits:
#     567     # Evaluations and gradients are paired, so that
#     568     # devices can re-use the device state for the
#     569     # gradient computation (if applicable).
#     570     res.append(self.batch_execute([circuit])[0])
# --> 571     jacs.append(gradient_method(circuit, **kwargs))
#     573 return res, jacs
#
# File ~/miniconda3/envs/qml_torch/lib/python3.10/site-packages/pennylane_lightning/lightning_qubit.py:603, in LightningQubit.adjoint_jacobian(self, tape, starting_state, use_device_state)
#     601         jac.extend(jac_local)
#     602 else:
# --> 603     jac = adjoint_diff.adjoint_jacobian(
#     604         processed_data["state_vector"],
#     605         processed_data["obs_serialized"],
#     606         processed_data["ops_serialized"],
#     607         trainable_params,
#     608     )
#     609 jac = np.array(jac)
#     610 jac = jac.reshape(-1, len(trainable_params))
#
# KeyboardInterrupt:

# %%
file_name="pennylane_default.csv"

def create_circuit(n_qubits):
    '''Example function for creating test circuit'''

    dev = qml.device("default.qubit", wires=n_qubits)
    
    @qml.qnode(dev, interface="torch", diff_method="adjoint")
    def circuit(params):
        # wall of single qubit operations
        for i in range(n_qubits):
            qml.RY(params[0, i]*np.pi, wires=i)
            
        # ladder of entangling operations
        for i in range(n_qubits):
            qml.IsingXX(params[1, i]*np.pi, wires=[i, (i+1)%n_qubits])

        return qml.expval(qml.PauliZ(0))
    
    return circuit


run_benchmark(range(2, 22), test_time, file_name)
